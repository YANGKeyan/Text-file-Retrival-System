# %%
import os
import nltk

# Download ancillary nltk packages if not already installed
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Croya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Define the directory containing the dataset
DATASET_DIR = 'dataset'

# Function to read text from a file
def read_text_from_file(file_path):
    with open(file_path, 'r', encoding='ISO-8859-1') as file:
        return file.read()

# Get a list of file paths in the dataset directory
file_paths = [os.path.join(DATASET_DIR, filename) for filename in os.listdir(DATASET_DIR)]

# Read text from each file and combine them into a single string
all_content = " ".join([read_text_from_file(file_path).lower() for file_path in file_paths])

# Split content into tokens
tokens = nltk.word_tokenize(all_content)
text = nltk.Text(tokens)

# %%
print('Number of tokens:', len(tokens))
# Out:
# Number of tokens: 587744

# %%
print('Number of unique words:', len(fdist.keys()))
# Out:
# Number of unique words: 16294

# %%
unique_words = [k for k in fdist.keys()]

unique_words_100 = unique_words[:100]
print("First 100 unique Words: "+ str(unique_words_100))
# Out:
# First 100 unique Words: ['singapore', ':', 'airlines', '(', 'sia', ')', 'on', 'tuesday', 'nov', '23', 'apologised', 'for', 'any', 'confusion', 'caused', 'by', 'an', 'email', 'to', 'customers', 'that', 'contained', 'information', 'about', 'quarantine', 'requirements', 'passengers', 'vaccinated', 'travel', 'lane', 'vtl', 'flights', 'malaysia', '.', 'under', 'the', 'arrangement', ',', 'fully', 'need', 'not', 'serve', 'upon', 'arrival', 'however', 'who', 'had', 'booked', '29', 'received', 'morning', 'covid-19', 'testing', 'and', 'said', 'there', 'have', 'been', '``', 'changes', "''", 'advisories', '\x93passengers', 'are', 'subject', 'medical', 'screening', 'seven', 'or', '10', 'days', 'at', 'first', 'point', 'of', 'entry', 'their', 'own', 'expense', '\x94', 'stated', 'it', 'also', 'requirement', 'will', 'apply', 'with', 'approval', 'letter', 'home', 'travelling', 'langkawi', 'checks', 'cna', 'found', 'sq108', 'sq8582', 'were', 'among', 'those']

# %%
print('Common words that aren\'t stopwords')
print([w for w in list(fdist.keys())[:100]
   if w.lower() not in nltk.corpus.stopwords.words('english')])
# Out:
# Common words that aren't stopwords
# ['singapore', ':', 'airlines', '(', 'sia', ')', 'tuesday', 'nov', '23', 'apologised', 'confusion', 'caused', 'email', 'customers', 'contained', 'information', 'quarantine', 'requirements', 'passengers', 'vaccinated', 'travel', 'lane', 'vtl', 'flights', 'malaysia', '.', 'arrangement', ',', 'fully', 'need', 'serve', 'upon', 'arrival', 'however', 'booked', '29', 'received', 'morning', 'covid-19', 'testing', 'said', '``', 'changes', "''", 'advisories', '\x93passengers', 'subject', 'medical', 'screening', 'seven', '10', 'days', 'first', 'point', 'entry', 'expense', '\x94', 'stated', 'also', 'requirement', 'apply', 'approval', 'letter', 'home', 'travelling', 'langkawi', 'checks', 'cna', 'found', 'sq108', 'sq8582', 'among']

# %%
print('Long words that aren\'t URLs')
print([w for w in fdist.keys() if len(w) > 15 and 'http' not in w])
# Out:
# Long words that aren't URLs
# ...

# %%
print('Number of URLs: ',len([w for w in fdist.keys() if 'http' in w]))
# Out:
# Number of URLs:  1

# %%
print('Top 10 Most Common Words')
print(fdist.most_common(10))
# Out:
# Top 10 Most Common Words
# [('the', 26160), (',', 25944), ('.', 19664), ('to', 17114), ('and', 12365), ('of', 11966), ('a', 10405), ('in', 9092), ('for', 6235), ('that', 5971)]

# %%
fdist = text.vocab()
print(fdist["covid"])
print(fdist["covid-19"])
print(fdist["property"])
print(fdist["vtl"])
print(fdist["omicron"])
# Out:
# 55
# 2328
# 85
# 634
# 491

# %%
text.concordance("covid")
# Out:
# Displaying 25 of 55 matches:
# ve a national health service ( nhs ) covid pass proving ones vaccination statu
# orities want to ) only recognise nhs covid pass from the uk as a legitimate pla
# , caas said it is aware that the nhs covid pass is only available to those aged
# on , but are unable to obtain an nhs covid pass , they may write to the safe tr
# ireland , which does not use the nhs covid pass , even though it is part of the
# he uk . instead , the territory uses covid certificates issued by its own healt
# ovidcert ni app is in the eu digital covid certificate format , which is an acc
# e uk to include the northern ireland covid certificate . individuals holding th
# issued in the european union digital covid certificate ( eu dcc ) format as val
# inundated with a lot of things about covid and working from home . i have stude
# issued in the european union digital covid certificate ( eu dcc ) format as val
# ...

# %%
text.concordance("covid-19")
# Out:
# Displaying 25 of 2328 matches:
#  an email on tuesday morning about covid-19 testing and quarantine requirement
#  our comprehensive coverage of the covid-19 pandemic and its developments down
# d nea . since the beginning of the covid-19 pandemic , uvc disinfection device
# ting products that protect against covid-19 . related : demand for part-time h
# home cleaning services spikes amid covid-19 pandemic there 's 'always a risk '
# eeping its employees safe amid the covid-19 pandemic sanitation nation : how c
# 9 pandemic sanitation nation : how covid-19 created a home hygiene boom bookma
#  our comprehensive coverage of the covid-19 pandemic and its developments down
# l face challenges getting proof of covid-19 jabs vtl travellers from us to sin
# uals receiving the pfizer-biontech covid-19 vaccine are only considered fully
# the vtl , because of the different covid-19 certification systems across the u
# ...

# %%
text.concordance("property")
# Out:
# Displaying 25 of 85 matches:
# pply for a flat in the area , said property analysts . mr lee sze teck , head
# dishonestly inducing a delivery of property . the charges relate to lim cheat
# dishonestly inducing a delivery of property . the charges relate to lim cheat
# ake a serious view of intellectual property rights infringements , especially
# dishonestly inducing a delivery of property . the charges relate to lim cheat
# iors live together in each private property facility , with care , meals , cle
#  higher on 12 days . singapore : a property agent was fined s $ 12,000 on wedn
#  and therefore not eligible to buy property in singapore . she requested that
#  media release , cea stressed that property agencies and agents are not allowe
# y party in the sale or purchase of property in singapore and the lease of hdb
#  in singapore and the lease of hdb property . this regulation is to protect c
# to hand transaction funds to their property agencies and agents or make such r
# ...

# %%
text.concordance("vtl")
# Out:
# Displaying 25 of 634 matches:
# assengers on vaccinated travel lane ( vtl ) flights to malaysia . under the vtl
# vtl ) flights to malaysia . under the vtl arrangement , fully vaccinated passen
#  . however , customers who had booked vtl flights to malaysia on nov 29 receive
# hecks by cna found that passengers on vtl flights sq108 and sq8582 were among t
# sory to make clear that passengers on vtl flights will be able to enter their d
# n without needing to quarantine . the vtl arrangement between changi airport an
# re under its vaccinated travel lane ( vtl ) scheme due to certain gaps in the s
# e to certain gaps in the system . the vtl scheme , which allows quarantine-free
# d below 12 are allowed to board these vtl flights . why penalise the children
#  pass , they are not eligible for the vtl . ' '' in an email from the civil and
# uthenticate and verify safeguards the vtl and public health ,  said the email
# ...

# %%
text.concordance("omicron")
# Out:
# Displaying 25 of 491 matches:
# hich now has 41. singapore tracking omicron variant singapore is tracking the e
#  singapore is tracking the emerging omicron variant of covid-19 `` very closely
# l the things we love to do . '' the omicron variant has been classed `` of conc
# d : singapore tracking the emerging omicron covid-19 variant very closely : pm
# lee singapore tracking the emerging omicron covid-19 variant very closely : pm
#  to contain the new variant , named omicron , amid reports it is potentially mo
# nday that singapore is tracking the omicron variant very closely and could be f
# d : singapore tracking the emerging omicron covid-19 variant very closely : pm
#  singapore is tracking the emerging omicron covid-19 variant 'very closely ' ,
# ng . we 've learnt a new word  the omicron variant . we are tracking this very
#  along the way as possible . '' the omicron variant has been designated `` of c
# ...

# %%
text.collocations()
# Out:
# per cent; comprehensive coverage; telegram channel; developments
# download; latest updates; coronavirus outbreak; health risk; land vtl;
# assoc prof; antigen rapid; changi airport; omicron variant; infectious
# diseases; home recovery; pcr test; covid-19 cases; //cna.asia/telegram
# singapore; covid-19 pandemic; internal security; vaccinated travel

# %%
def count_occurrences_in_files(folder_path, keyword):

    count = 0

    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, "r", encoding="ISO-8859-1") as file:
                content = file.read().lower() 
                if keyword in content: 
                    count += 1

    return count

# %%
folder_path = "dataset"
keyword = "singapore"
result = count_occurrences_in_files(folder_path, keyword)
print(f"The number of files containing'{keyword}': {result}")
# Out:
# The number of files containing'singapore': 544

# %%
folder_path = "dataset"
keyword = "covid"
result = count_occurrences_in_files(folder_path, keyword)
print(f"The number of files containing'{keyword}': {result}")
# Out:
# The number of files containing'covid': 327

# %%
folder_path = "dataset"
keyword = "omicron"
result = count_occurrences_in_files(folder_path, keyword)
print(f"The number of files containing'{keyword}': {result}")
# Out:
# The number of files containing'omicron': 102

# %%
from nltk.corpus import stopwords
import string

# Download stopwords list if not already downloaded
nltk.download('stopwords')

# Get the list of stopwords
stop_words = set(stopwords.words('english'))

# Define a translation table to remove punctuation
translator = str.maketrans('', '', string.punctuation)

# Remove stopwords, digits, and punctuation
filtered_tokens = [word.translate(translator) for word in text if word.isalpha() and word.lower() not in stop_words]

# Create a new NLTK Text object from filtered tokens
filtered_text = nltk.Text(filtered_tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Croya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Define words to remove
words_to_remove = {'mr', 'ms', 'per', 'one', 'also', 'would', 'have', 'could', 'can','said'}

# Remove specified words
filtered_text_without_specific_words = [word for word in filtered_text if word.lower() not in words_to_remove]

# Create a new NLTK Text object from filtered tokens
final_text = nltk.Text(filtered_text_without_specific_words)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Join the words back into a single string
final_text_as_string = ' '.join(final_text)

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(final_text_as_string)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
from gensim import corpora, models

# Create a dictionary representation of the documents
dictionary = corpora.Dictionary([final_text])

# Create a corpus from a list of texts
corpus = [dictionary.doc2bow(final_text)]

# Train the LDA model
lda_model = models.LdaModel(corpus, num_topics=5, id2word=dictionary, passes=15)

# Print the topics
for topic in lda_model.print_topics():
    print(topic)
# Out:
# (0, '0.013*"singapore" + 0.004*"health" + 0.004*"test" + 0.004*"people" + 0.004*"added" + 0.004*"cases" + 0.004*"new" + 0.004*"moh" + 0.003*"home" + 0.003*"travel"')
# (1, '0.001*"singapore" + 0.000*"people" + 0.000*"test" + 0.000*"travel" + 0.000*"moh" + 0.000*"new" + 0.000*"health" + 0.000*"two" + 0.000*"photo" + 0.000*"years"')
# (2, '0.003*"singapore" + 0.001*"test" + 0.001*"added" + 0.001*"home" + 0.001*"cases" + 0.001*"people" + 0.001*"new" + 0.001*"need" + 0.001*"moh" + 0.001*"vaccinated"')
# (3, '0.001*"singapore" + 0.000*"health" + 0.000*"test" + 0.000*"added" + 0.000*"people" + 0.000*"cases" + 0.000*"new" + 0.000*"moh" + 0.000*"home" + 0.000*"need"')
# (4, '0.001*"singapore" + 0.000*"new" + 0.000*"people" + 0.000*"cent" + 0.000*"moh" + 0.000*"cases" + 0.000*"test" + 0.000*"health" + 0.000*"added" + 0.000*"years"')
